# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot  as plt
import warnings
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
train.fillna("")
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL        65.0     8450   Pave            Reg
# 1        2          20       RL        80.0     9600   Pave            Reg
# 2        3          60       RL        68.0    11250   Pave            IR1
# 3        4          70       RL        60.0     9550   Pave            IR1
# 4        5          60       RL        84.0    14260   Pave            IR1
# ...    ...         ...      ...         ...      ...    ...   ...      ...
# 1455  1456          60       RL        62.0     7917   Pave            Reg
# 1456  1457          20       RL        85.0    13175   Pave            Reg
# 1457  1458          70       RL        66.0     9042   Pave            Reg
# 1458  1459          20       RL        68.0     9717   Pave            Reg
# 1459  1460          20       RL        75.0     9937   Pave            Reg
#
# ...

# %%
train.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
la= LabelEncoder()

# %%
dobject=train.select_dtypes(include="object")
nobject=train.select_dtypes(exclude="object")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-bbb83ea54731> in <module>
# ----> 1 dobject=train.select_dtypes(include="object")
#       2 nobject=train.select_dtypes(exclude="object")
#
# AttributeError: 'NoneType' object has no attribute 'select_dtypes'

# %%
nobject.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   OverallQual    1460 non-null   int64
#  5   OverallCond    1460 non-null   int64
#  6   YearBuilt      1460 non-null   int64
#  7   YearRemodAdd   1460 non-null   int64
#  8   MasVnrArea     1452 non-null   float64
#  9   BsmtFinSF1     1460 non-null   int64
#  10  BsmtFinSF2     1460 non-null   int64
#  11  BsmtUnfSF      1460 non-null   int64
#  12  TotalBsmtSF    1460 non-null   int64
#  13  1stFlrSF       1460 non-null   int64
#  14  2ndFlrSF       1460 non-null   int64
#  15  LowQualFinSF   1460 non-null   int64
#  16  GrLivArea      1460 non-null   int64
#  17  BsmtFullBath   1460 non-null   int64
# ...

# %%
nobject.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
nobject.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
df = pd.DataFrame(nobject)
imp = SimpleImputer(missing_values=np.nan, strategy="most_frequent")

df_imputed = pd.DataFrame(imp.fit_transform(df),columns=df.columns)

# %%
for i in range(0,dobject.shape[1]):
     dobject.iloc[:,i]=la.fit_transform( dobject.iloc[:,i])

# %%
ntrain=pd.concat([dobject,nobject],axis=1)

# %%
ntrain.isnull().sum()
# Out:
# MSZoning       0
# Street         0
# Alley          0
# LotShape       0
# LandContour    0
#               ..
# PoolArea       0
# MiscVal        0
# MoSold         0
# YrSold         0
# SalePrice      0
# Length: 81, dtype: int64

# %%
ntrain.head(20)
# Out:
#    MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0         3      1     2        3           3         0         4         0
# 1         3      1     2        3           3         0         2         0
# 2         3      1     2        0           3         0         4         0
# 3         3      1     2        0           3         0         0         0
# 4         3      1     2        0           3         0         2         0
# 5         3      1     2        0           3         0         4         0
# 6         3      1     2        3           3         0         4         0
# 7         3      1     2        0           3         0         0         0
# 8         4      1     2        3           3         0         4         0
# 9         3      1     2        3           3         0         0         0
# 10        3      1     2        3           3         0         4         0
# ...

# %%
x=ntrain.drop("SalePrice",axis=1)
y=ntrain["SalePrice"]
#ff=["PoolArea","LotArea"]
xtest=test[ff]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(missing_values=np.nan, strategy='mean')),
    ('regressor', LinearRegression())
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()),
#                 ('regressor', LinearRegression())])

# %%
predictions = pipeline.predict(x_test)
print(predictions)
# Out:
# [148868.97396652 318551.24214985 110498.47595245 180838.99747321
#  313295.83011369  74707.48943631 231488.26317609 147008.93829262
#   73862.90629527 152440.68810891 152223.04901474 107366.08705384
#   73657.268049   208342.03074922 165739.07636793 137479.26841152
#  214142.25083989 115107.40437936 114088.35946549 231622.95231113
#  132650.50242663 209331.03763604 189264.18304356 118302.3358933
#  218672.43825723 162140.26072926 211481.59960342  73813.19309783
#  164859.71564537 198445.33771503 164539.33435503 257116.8532957
#  176863.75768787 102237.07102583 251908.9159602  148388.51204892
#  119261.60303639 218120.26153174 290336.23541133  92579.30735848
#  116320.89976793 253676.26352248 111368.52497934 320462.17947381
#  124886.92455767 150630.50113946  94628.49581255 135579.31260255
#  395277.98167968 123282.81419096 116399.92419858 216339.82870792
#  103632.18366877 361150.47308083 152376.4355643  244494.77701978
# ...

# %%
test.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
dobjectest=test.select_dtypes(include="object")
nobjectest=test.select_dtypes(exclude="object")
for i in range(0,dobject.shape[1]):
     dobjectest.iloc[:,i]=la.fit_transform( dobjectest.iloc[:,i])

# %%
ntest=pd.concat([dobjectest,nobjectest],axis=1)
ntest.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0        2      1     2        3           3         0         4         0
# 1        3      1     2        0           3         0         0         0
# 2        3      1     2        0           3         0         4         0
# 3        3      1     2        0           3         0         4         0
# 4        3      1     2        0           1         0         4         0
#
#   Neighborhood Condition1  ... GarageArea WoodDeckSF OpenPorchSF  \
# 0           12          1  ...      730.0        140           0
# 1           12          2  ...      312.0        393          36
# 2            8          2  ...      482.0        212          34
# 3            8          2  ...      470.0        360          36
# 4           22          2  ...      506.0          0          82
#
#   EnclosedPorch 3SsnPorch ScreenPorch PoolArea MiscVal MoSold YrSold
# ...

# %%
ntest.isnull().sum()
# Out:
# MSZoning       0
# Street         0
# Alley          0
# LotShape       0
# LandContour    0
#               ..
# ScreenPorch    0
# PoolArea       0
# MiscVal        0
# MoSold         0
# YrSold         0
# Length: 80, dtype: int64

# %%
dff = pd.DataFrame(ntest)
impp = SimpleImputer(missing_values=np.nan, strategy="most_frequent")

df_imputed = pd.DataFrame(impp.fit_transform(dff),columns=dff.columns)

# %%
ff=ntest

# %%
test_predictions = pipeline.predict(ff)

# %%
print(test_predictions)
# Out:
# [205729.38040398 254848.67843513 265648.36347954 ... 237056.67224372
#  212968.24007354 336657.68343936]
